# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join

# %%
files_in_dir = [ f for f in listdir('./limfast-master/limfast_bt/Boxes/') 
                if isfile(join('./limfast-master/limfast_bt/Boxes/',f)) ]

# %%
# SFRD
files = np.array([])
values = np.array([])
for a in range(len(files_in_dir)):
    file = str(files_in_dir[a])
    #print file
    if 'SFRD_z' in file and '200_500Mpc' in file:
        files = np.append(files,file)
        values = np.append(values,float(str(file[6:12])))
        #print '../Boxes/'+file
sorteds =  files[np.argsort(values)]
for b in range(len(sorteds)):
    print '../Boxes/'+sorteds[b]
print ' '


# Z 
"""files = np.array([])
values = np.array([])
for a in range(len(files_in_dir)):
    file = str(files_in_dir[a])
    #print file
    if 'SFRD_z' in file and '200_500Mpc' in file:
        files = np.append(files,file)
        values = np.append(values,float(str(file[6:12])))
        #print '../Boxes/'+file
sorteds =  files[np.argsort(values)]
for b in range(len(sorteds)):
    print '../Boxes/'+sorteds[b]
print ' '"""


# Lya SF  I_HI1216A_z013.06_HIIfilter1_RHIImax50_200_500Mpc
files = np.array([])
values = np.array([])
for a in range(len(files_in_dir)):
    file = str(files_in_dir[a])
    #print file
    if 'I_HI1216A_z' in file and '200_500Mpc' in file and '_z0_' not in file:
        files = np.append(files,file)
        values = np.append(values,float(str(file[11:17])))
        #print '../Boxes/'+file
sorteds =  files[np.argsort(values)]
print values
for b in range(len(sorteds)):
    print '../Boxes/'+sorteds[b]
print ' '


# Lya IGM I_HI1216AdIGM_z011.00_HIIfilter1_RHIImax50_200_500Mpc
files = np.array([])
values = np.array([])
for a in range(len(files_in_dir)):
    file = str(files_in_dir[a])
    #print file
    if 'I_HI1216AdIGM_z' in file and '200_500Mpc' in file and '_z0_' not in file:
        files = np.append(files,file)
        values = np.append(values,float(str(file[15:21])))
        #print '../Boxes/'+file
sorteds =  files[np.argsort(values)]
print values
for b in range(len(sorteds)):
    print '../Boxes/'+sorteds[b]
print ' '



# Ha SF  I_HI6563A_z013.06_HIIfilter1_RHIImax50_200_500Mpc
files = np.array([])
values = np.array([])
for a in range(len(files_in_dir)):
    file = str(files_in_dir[a])
    #print file
    if 'I_HI6563A_z' in file and '200_500Mpc' in file and '_z0_' not in file:
        files = np.append(files,file)
        values = np.append(values,float(str(file[11:17])))
        #print '../Boxes/'+file
sorteds =  files[np.argsort(values)]
print values
for b in range(len(sorteds)):
    print '../Boxes/'+sorteds[b]
print ' '



# OII SF  I_OII3726A_z013.06_HIIfilter1_RHIImax50_200_500Mpc
files = np.array([])
values = np.array([])
for a in range(len(files_in_dir)):
    file = str(files_in_dir[a])
    #print file
    if 'I_OII3726A_z' in file and '200_500Mpc' in file and '_z0_' not in file:
        files = np.append(files,file)
        values = np.append(values,float(str(file[12:18])))
        #print '../Boxes/'+file
sorteds =  files[np.argsort(values)]
print values
for b in range(len(sorteds)):
    print '../Boxes/'+sorteds[b]
print ' '


# OIII SF  I_OIII5007A_z013.06_HIIfilter1_RHIImax50_200_500Mpc
files = np.array([])
values = np.array([])
for a in range(len(files_in_dir)):
    file = str(files_in_dir[a])
    #print file
    if 'I_OIII5007A_z' in file and '200_500Mpc' in file and '_z0_' not in file:
        files = np.append(files,file)
        values = np.append(values,float(str(file[13:19])))
        #print '../Boxes/'+file
sorteds =  files[np.argsort(values)]
print values
for b in range(len(sorteds)):
    print '../Boxes/'+sorteds[b]
print ' '


# xHI  xH_nohalos_z010.77_nf0.882669_Fstar0.0500_starPL0.5000_Fesc0.1000_escPL-0.5000_Mturn5.00e+08_HIIfilter1_RHIImax50_200_500Mpc
files = np.array([])
values = np.array([])
for a in range(len(files_in_dir)):
    file = str(files_in_dir[a])
    #print file
    if 'xH_nohalos_z' in file and '200_500Mpc' in file and '_z0_' not in file:
        files = np.append(files,file)
        values = np.append(values,float(str(file[12:18])))
        #print '../Boxes/'+file
sorteds =  files[np.argsort(values)]
print values
for b in range(len(sorteds)):
    print '../Boxes/'+sorteds[b]
print ' '


# delta T 21cm   delta_T_z009.66_nf0.804213_useTs1_200_500Mpc
files = np.array([])
values = np.array([])
for a in range(len(files_in_dir)):
    file = str(files_in_dir[a])
    #print file
    if 'delta_T_z' in file and 'useTs1_200_500Mpc' in file and '_z0_' not in file:
        files = np.append(files,file)
        values = np.append(values,float(str(file[9:15])))
        #print '../Boxes/'+file
sorteds =  files[np.argsort(values)]
print values
for b in range(len(sorteds)):
    print '../Boxes/'+sorteds[b]
print ' '


# gas mass  gas_mass_z008.65_HIIfilter1_RHIImax50_200_500Mpc
files = np.array([])
values = np.array([])
for a in range(len(files_in_dir)):
    file = str(files_in_dir[a])
    #print file
    if 'gas_mass_z' in file and '200_500Mpc' in file and '_z0_' not in file:
        files = np.append(files,file)
        values = np.append(values,float(str(file[10:16])))
        #print '../Boxes/'+file
sorteds =  files[np.argsort(values)]
print values
for b in range(len(sorteds)):
    print '../Boxes/'+sorteds[b]
print ' '


# metal mass  metal_mass_z008.65_HIIfilter1_RHIImax50_200_500Mpc
files = np.array([])
values = np.array([])
for a in range(len(files_in_dir)):
    file = str(files_in_dir[a])
    #print file
    if 'metal_mass_z' in file and '200_500Mpc' in file and '_z0_' not in file:
        files = np.append(files,file)
        values = np.append(values,float(str(file[12:18])))
        #print '../Boxes/'+file
sorteds =  files[np.argsort(values)]
print values
for b in range(len(sorteds)):
    print '../Boxes/'+sorteds[b]
print ' '
# Out:
# ../Boxes/SFRD_z005.00_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z005.12_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z005.24_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z005.37_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z005.50_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z005.63_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z005.76_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z005.89_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z006.03_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z006.17_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z006.31_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z006.46_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z006.61_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z006.76_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z006.92_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z007.08_HIIfilter1_RHIImax50_200_500Mpc
# ../Boxes/SFRD_z007.24_HIIfilter1_RHIImax50_200_500Mpc
# ...
